# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# **Date and time problems**

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
df.Gender = df.Gender.astype("category")
df.Team = df.Team.astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# **Easy Way**

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df.Gender = df.Gender.astype("category")
df.Team = df.Team.astype("category")

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# ## Filter A Dataframe Based On Condition

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.Gender == "Male"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df.Gender == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-03-19 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-03-19 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-03-19 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-03-19 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-03-19 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-03-19 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-03-19 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-03-19 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
cond = df.Team == "Finance"

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-19 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-03-19 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-03-19 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-03-19 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-03-19 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-03-19 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-03-19 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-03-19 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-03-19 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
cond = df["Senior Management"]

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-03-19 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-19 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-03-19 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-03-19 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-03-19 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-03-19 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-03-19 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2022-03-19 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %%
cond = df.Team != "Marketing"

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-19 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-19 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-03-19 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-03-19 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-03-19 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-03-19 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-03-19 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-03-19 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [902 rows x 8 columns]

# %%
cond = df.Salary >= 100000

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-19 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-19 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-03-19 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2022-03-19 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2022-03-19 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2022-03-19 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-03-19 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2022-03-19 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2022-03-19 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 9                 True  Business Development
# ..                 ...                   ...
# 990               True       Client Services
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [409 rows x 8 columns]

# %%
cond = df["Bonus %"] < 1.5

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2022-03-19 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2022-03-19 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2022-03-19 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2022-03-19 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2022-03-19 20:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02 2022-03-19 03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03 2022-03-19 16:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12 2022-03-19 20:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08 2022-03-19 19:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19 2022-03-19 01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12 2022-03-19 01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27 2022-03-19 06:40:00   93847    1.085
# 527      Helen     NaN 1993-12-02 2022-03-19 13:42:00   45724    1.022
# 570      Kelly  Female 1996-08-16 2022-03-19 03:09:00   41427    1.431
# 578     Amanda  Female 1982-03-17 2022-03-19 23:46:00  107111    1.438
# 579     Harold    Male 2010-10-18 2022-03-19 20:45:00   65673    1.187
# 617      Kathy  Female 2001-01-14 2022-03-19 05:11:00   45682    1.451
# 618      Peter    Male 1992-11-24 2022-03-19 17:43:00   69297    1.268
# 638    Frances  Female 1996-11-12 2022-03-19 18:08:00  112467    1.433
# 652     Willie    Male 2009-12-05 2022-03-19 05:39:00  141932    1.017
# 708      Steve    Male 2002-01-11 2022-03-19 21:17:00   51821    1.197
# 732      Henry    Male 1986-05-12 2022-03-19 02:04:00   59943    1.432
# 734        NaN  Female 1994-12-18 2022-03-19 20:42:00  138807    1.400
# 746     Gloria  Female 2004-08-19 2022-03-19 10:31:00   46602    1.027
# 912        Joe    Male 1998-12-08 2022-03-19 10:28:00  126120    1.020
# 929    Theresa  Female 2001-04-27 2022-03-19 21:17:00   75661    1.079
# 954        Joe    Male 1980-01-19 2022-03-19 16:06:00  119667    1.148
# 997    Russell    Male 2013-05-20 2022-03-19 12:39:00   96914    1.421
#
#      Senior Management                  Team
# 4                 True       Client Services
# 15               False               Product
# 58                True           Engineering
# 77                True             Marketing
# 175               True           Engineering
# 189              False                 Sales
# 217               True       Client Services
# 273               True               Product
# 279              False  Business Development
# 365              False       Human Resources
# 445              False                   NaN
# 481               True  Business Development
# 527              False               Product
# 570              False               Product
# 578               True               Product
# 579               True                 Legal
# 617               True             Marketing
# 618              False               Finance
# 638              False  Business Development
# 652               True           Engineering
# 708               True                 Legal
# 732              False               Finance
# 734               True       Human Resources
# 746               True  Business Development
# 912              False                   NaN
# 929               True                 Legal
# 954               True               Finance
# 997              False               Product

# %%
cond = df["Start Date"] <= "1985-01-01"

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2022-03-19 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2022-03-19 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2022-03-19 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2022-03-19 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2022-03-19 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2022-03-19 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2022-03-19 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2022-03-19 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2022-03-19 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2022-03-19 06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %% [markdown]
# ## Multiple Conditions

# %%
cond1 = df.Gender == "Male"
cond2 = df.Team == "Marketing"
cond3 = df.Salary >= 100000

# %%
df[cond1 & (cond2 | cond3)]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 3        Jerry   Male 2005-03-04 2022-03-19 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-03-19 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-03-19 01:35:00  115163   10.125
# 12     Brandon   Male 1980-12-01 2022-03-19 01:08:00  112807   17.492
# ..         ...    ...        ...                 ...     ...      ...
# 981      James   Male 1993-01-15 2022-03-19 17:19:00  148985   19.280
# 983       John   Male 1982-12-23 2022-03-19 22:35:00  146907   11.738
# 992    Anthony   Male 2011-10-16 2022-03-19 08:35:00  112769   11.625
# 994     George   Male 2013-06-21 2022-03-19 17:47:00   98874    4.479
# 999     Albert   Male 2012-05-15 2022-03-19 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# 12                True  Human Resources
# ..                 ...              ...
# 981              False            Legal
# 983              False      Engineering
# 992               True          Finance
# 994               True        Marketing
# 999               True            Sales
#
# [204 rows x 8 columns]

# %% [markdown]
# ## .isin( ) Method

# %%
cond = df.Team.isin(["Legal", "Sales", "Product"])

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-03-19 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-03-19 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-03-19 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-03-19 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-03-19 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-03-19 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-03-19 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-03-19 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-03-19 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-03-19 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ## The .isnull() and .notnull() Methods

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
condis = df.Team.isnull()
condnot = df.Team.notnull()

# %%
df[condis].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2022-03-19 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2022-03-19 16:19:00  125792    5.042
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN

# %%
df[condnot].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 2      Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-19 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 2              False    Finance
# 3               True    Finance

# %% [markdown]
# ## The .between() Method

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
cond = df.Salary.between(60000, 70000)

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2022-03-19 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2022-03-19 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2022-03-19 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2022-03-19 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2022-03-19 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2022-03-19 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2022-03-19 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2022-03-19 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2022-03-19 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
cond = df["Bonus %"].between(2.0, 5.0)

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2022-03-19 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2022-03-19 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2022-03-19 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2022-03-19 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2022-03-19 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2022-03-19 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2022-03-19 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2022-03-19 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2022-03-19 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# 40                True  Distribution
# 49               False         Sales
# 60               False  Distribution
# ..                 ...           ...
# 943              False   Engineering
# 961              False         Legal
# 976               True         Legal
# 989              False         Legal
# 994               True     Marketing
#
# [169 rows x 8 columns]

# %%
cond = df["Start Date"].between("1999-01-01", "2000-01-01")

# %%
df[cond]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 26       Craig    Male  2/27/2000         7:45 AM   37598    7.757
# 31       Joyce     NaN  2/20/2005         2:40 PM   88657   12.752
# 36      Rachel  Female  2/16/2009         8:47 PM  142032   12.599
# 52        Todd    Male  2/18/1990         2:41 AM   49339    1.695
# 85      Jeremy    Male   2/1/2008         8:50 AM  100238    3.887
# ..         ...     ...        ...             ...     ...      ...
# 923      Irene     NaN  2/28/1991        10:23 PM  135369    4.380
# 953      Randy    Male  2/25/2012         5:33 AM   57266   14.077
# 957    Jeffrey    Male   2/3/1984         1:26 PM   70990   15.901
# 969      Linda  Female   2/4/2010         8:49 PM   44486   17.308
# 989     Justin     NaN  2/10/1991         4:58 PM   38344    3.794
#
#     Senior Management                  Team
# 26               True             Marketing
# 31              False               Product
# 36              False  Business Development
# 52               True       Human Resources
# 85               True       Client Services
# ..                ...                   ...
# 923             False  Business Development
# 953             False               Product
# 957              True                 Sales
# 969              True           Engineering
# 989             False                 Legal
#
# [78 rows x 8 columns]

# %%
cond = df["Last Login Time"].between("08:30AM", "9:00AM")

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 85      Jeremy    Male 2008-02-01 2022-03-19 08:50:00  100238    3.887
# 96     Cynthia  Female 1994-03-21 2022-03-19 08:34:00  142321    1.737
# 121   Kathleen     NaN 2016-05-09 2022-03-19 08:55:00  119735   18.740
# 157        NaN  Female 2005-07-27 2022-03-19 08:32:00   79536   14.443
# 259      Henry    Male 1995-02-06 2022-03-19 08:34:00   89258   15.585
# 345     Steven    Male 2006-11-21 2022-03-19 08:30:00   83706    6.960
# 385      Debra  Female 2010-01-19 2022-03-19 08:48:00   70492    8.895
# 397   Clarence    Male 2005-01-13 2022-03-19 09:00:00  116693   13.835
# 429       Rose  Female 2015-05-28 2022-03-19 08:40:00  149903    5.630
# 446     Cheryl  Female 1994-08-16 2022-03-19 08:33:00   67150   15.850
# 557       Jane  Female 1994-06-01 2022-03-19 08:39:00   42424   18.115
# 807       Mary  Female 2011-11-06 2022-03-19 08:32:00  115057    2.089
# 828    Cynthia  Female 2006-07-12 2022-03-19 08:55:00  149684    7.864
# 840    Lillian  Female 2002-08-26 2022-03-19 08:53:00  103854    4.924
# 852      Diana  Female 2004-11-19 2022-03-19 08:47:00  105066   17.343
# 885       Juan    Male 1993-10-06 2022-03-19 08:52:00   85871    9.160
# 887      David    Male 2009-12-05 2022-03-19 08:48:00   92242   15.407
# 906    Frances  Female 2014-05-16 2022-03-19 08:31:00   35884   17.667
# 922     Arthur    Male 2013-12-05 2022-03-19 08:44:00   86615    3.412
# 941    William    Male 1997-06-26 2022-03-19 08:33:00  104840   15.653
# 992    Anthony    Male 2011-10-16 2022-03-19 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 85                True       Client Services
# 96               False               Finance
# 121              False               Product
# 157               True               Product
# 259               True       Human Resources
# 345               True       Human Resources
# 385              False       Client Services
# 397               True          Distribution
# 429              False       Human Resources
# 446               True             Marketing
# 557              False          Distribution
# 807              False               Finance
# 828              False               Product
# 840               True          Distribution
# 852               True  Business Development
# 885              False               Product
# 887              False                 Legal
# 906              False                 Sales
# 922               True  Business Development
# 941               True           Engineering
# 992               True               Finance

# %% [markdown]
# ## The .duplicated( ) Method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df.Gender = df.Gender.astype("category")
df.Team = df.Team.astype("category")
df.sort_values("First Name", inplace=True)

# %%
cond = ~df["First Name"].duplicated(keep = False)

# %%
df[cond]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-03-19 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-03-19 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-03-19 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-03-19 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-03-19 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-03-19 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-03-19 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-03-19 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-03-19 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# ## .drop_duplicates( ) Method

# %%
df.sort_values("First Name", inplace=True)

# %%
df.head(4)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-19 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-03-19 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-03-19 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-03-19 19:39:00   63126   18.424
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services

# %%
df.shape
# Out:
# (1000, 8)

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates(subset = ["First Name"], keep="first").head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-19 10:20:00   61602   11.849
# 137       Adam   Male 2011-05-21 2022-03-19 01:45:00   95327   15.120
# 300       Alan   Male 1988-06-26 2022-03-19 03:54:00  111786    3.592
#
#      Senior Management          Team
# 101               True     Marketing
# 137              False  Distribution
# 300               True   Engineering

# %%
df.drop_duplicates(subset = ["First Name"], keep="last").head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron    NaN 1986-01-22 2022-03-19 19:39:00   63126   18.424
# 538       Adam   Male 2010-10-08 2022-03-19 21:53:00   45181    3.491
# 610       Alan   Male 2012-02-17 2022-03-19 00:26:00   41453   10.084
#
#      Senior Management             Team
# 937              False  Client Services
# 538              False  Human Resources
# 610              False          Product

# %%
df.drop_duplicates(subset = ["First Name", "Team"]).head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-19 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2022-03-19 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2022-03-19 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services
# 137              False     Distribution

# %% [markdown]
# ## The .unique( ) and .nunique( ) Methods

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df.Gender = df.Gender.astype("category")
df.Team = df.Team.astype("category")

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-19 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-19 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-19 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.Gender.unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
df.Team.unique()
# Out:
# ['Marketing', NaN, 'Finance', 'Client Services', 'Legal', ..., 'Engineering', 'Business Development', 'Human Resources', 'Sales', 'Distribution']
# Length: 11
# Categories (10, object): ['Business Development', 'Client Services', 'Distribution', 'Engineering', ..., 'Legal', 'Marketing', 'Product', 'Sales']

# %%
df.Team.nunique()
# Out:
# 10
